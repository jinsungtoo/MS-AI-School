# %%
# !pip install azure-eventhub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 150 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 41.3 MB/s
# ...
#      |████████████████████████████████| 172 kB 40.6 MB/s
# ...

# %%
from azure.eventhub.aio import EventHubProducerClient
from azure.eventhub import EventData

# %%
eventhub = EventHubProducerClient.from_connection_string(conn_str='Endpoint=sb://labuser16eventhub.servicebus.windows.net/;SharedAccessKeyName=me;SharedAccessKey=A9sZlEdfVI9jwPmZOugdICorCRduLk/85s5lmyWsXrg=;EntityPath=event1')

# %%
import time
from datetime import datetime

i=0
while(1):
  message = 'time: ' + str(datetime.now())
  eventhub.send_event(EventData(message))

  i+=1
  if i%10==0:
    print('message {} sending...'.format(i))

  time.sleep(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: coroutine 'EventHubProducerClient.send_event' was never awaited
#   import sys
# ...
# message 10 sending...
# message 20 sending...
# message 30 sending...
# message 40 sending...
# message 50 sending...
# message 60 sending...
# message 70 sending...
# message 80 sending...
# message 90 sending...
# message 100 sending...
# message 110 sending...
# message 120 sending...
# message 130 sending...
# message 140 sending...
# message 150 sending...
# message 160 sending...
# message 170 sending...
# message 180 sending...
# message 190 sending...
# message 200 sending...
# message 210 sending...
# message 220 sending...
# message 230 sending...
# message 240 sending...
# message 250 sending...
# message 260 sending...
# message 270 sending...
# message 280 sending...
# message 290 sending...
# message 300 sending...
# message 310 sending...
# message 320 sending...
# message 330 sending...
# ...
