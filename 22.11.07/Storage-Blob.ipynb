# %%
# 패키지 설치
# !pip install azure-storage-blob
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 383 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 85 kB 2.2 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 45.7 MB/s
# ...
#      |████████████████████████████████| 172 kB 42.8 MB/s
# ...
#      |████████████████████████████████| 41 kB 294 kB/s
# ...

# %%
# 필요한 패키지 불러오기
import os, uuid
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient

# %%
# Blob 서비스에 연결합니다
connect_string = 'DefaultEndpointsProtocol=https;AccountName=labuser16storage2;AccountKey=KBiLCnVqQJjAC0Bdh7T1lwN+RnAR+x2hK8DYROO1wTffdtzXvsJlcpWXM9/6bvgfGAcpDJUbwvrI+ASt1vRiUw==;EndpointSuffix=core.windows.net'

blob_service_client = BlobServiceClient.from_connection_string(connect_string)

# %%
# Container 생성
container_name = str(uuid.uuid4())
print(container_name)

container_client = blob_service_client.create_container(container_name)
# Out:
# deb328fa-06b9-42e6-a1e7-eca42f445d3b

# %%
# 데이터를 업로드 한다

local_path ='./data'
os.mkdir(local_path)

local_file_name = str(uuid.uuid4()) + '.txt'
upload_file_path = os.path.join(local_path, local_file_name)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-16-dc57e09ceee3> in <module>
#       2
#       3 local_path ='./data'
# ----> 4 os.mkdir(local_path)
#       5
#       6 local_file_name = str(uuid.uuid4()) + '.txt'
#
# FileExistsError: [Errno 17] File exists: './data'

# %%
# 업로드 할 때 파일을 준비한다
file = open(file=upload_file_path, mode='w')
file.write('Hello Azure Storage')
file.close()

blob_client = blob_service_client.get_blob_client(container=container_name, # 파일이 들어갈 자리를 확보
                                                  blob= local_file_name
    
) # 파일 업로드
with open(file=upload_file_path, mode='rb') as data:
  blob_client.upload_blob(data)

# %%
# 파일의 목록의 확인
blob_list = container_client.list_blobs()
for blob in blob_list:
  print('\t' + blob.name)
# Out:
# 	f1655e6c-3f69-4a3b-bdb5-fe5f2949273d.txt

# %%
# 업로드된 파일의 다운로드 

download_file_path = os.path.join(local_path, 
                                  str.replace(local_file_name,'.txt','DOWNLOAD.txt'))
container_client = blob_service_client.get_container_client(container= container_name) 

with open(file=download_file_path, mode='wb') as download_file:
  download_file.write(container_client.download_blob(blob.name).readall()) #전체데이터 다운로드

# %%
# 실습한 자원의 정리
print('Press the Enter key to begin clean up')
input()

print('Deleting blob container...')
container_client.delete_container()

print('Deleting the local source and downloaded files...')
os.remove(upload_file_path)
os.remove(download_file_path)
os.rmdir(local_path)

print('Done')
# Out:
# Press the Enter key to begin clean up
#
# Deleting blob container...
# ---------------------------------------------------------------------------
# ResourceNotFoundError                     Traceback (most recent call last)
# <ipython-input-21-dd71fe3678c5> in <module>
#       4
#       5 print('Deleting blob container...')
# ----> 6 container_client.delete_container()
#       7
#       8 print('Deleting the local source and downloaded files...')
#
# /usr/local/lib/python3.7/dist-packages/azure/core/tracing/decorator.py in wrapper_use_tracer(*args, **kwargs)
#      76             span_impl_type = settings.tracing_implementation()
#      77             if span_impl_type is None:
# ---> 78                 return func(*args, **kwargs)
#      79
#      80             # Merge span is parameter is set, but only if no explicit parent are passed
#
# /usr/local/lib/python3.7/dist-packages/azure/storage/blob/_container_client.py in delete_container(self, **kwargs)
# ...
