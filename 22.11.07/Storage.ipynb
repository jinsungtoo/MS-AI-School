# %%
# !pip install azure-storage-file
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 47 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 14.8 MB/s
# ...

# %%
# 계정 연결
from azure.storage.file import FileService
file_service = FileService(account_name= 'labuser16storage2', # 스토리지 계정 이름
                           account_key='KBiLCnVqQJjAC0Bdh7T1lwN+RnAR+x2hK8DYROO1wTffdtzXvsJlcpWXM9/6bvgfGAcpDJUbwvrI+ASt1vRiUw==')

# %%
file_service.create_share('myshare')
# Out:
# True

# %%
# 디렉토리에 파일 생성
file_service.create_directory('myshare','sampledir')
# Out:
# True

# %%
# 파일에 이미지 업로드
from azure.storage.file import ContentSettings

file_service.create_file_from_path('myshare',
                                   None,
                                   'myfile',
                                   '7.jpg',
                                   content_settings=ContentSettings(content_type='image/jpg'))

# %%
# 파일 목록 확인
generator = file_service.list_directories_and_files('myshare')
for file_or_dir in generator:
  print(file_or_dir.name)
# Out:
# myfile
# sampledir

# %%
# 파일 가져오기
file_service.get_file_to_path('myshare',None,'myfile','out-7.jpg')
